# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('../Lance_TW/WS2_Al2O3/SmallRectangle/linecuts/top_206.txt',sep='\t',skiprows=2)
xlist = df.index
ylist = df.iloc[:,1].values
fig=plt.figure(figsize=(4,2))
fig.patch.set_facecolor('white')
plt.plot(xlist,ylist,color='black',linewidth=1)
plt.ylim(-1.75,4)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)

# plt.xlabel('position ($\mu$m)')
# plt.ylabel('iMIM signal (mV)')
# Out:
# (array([-2.,  0.,  2.,  4.]), <a list of 4 Text yticklabel objects>)
